# %%
import math

# %%
import os
from skimage.transform import resize
from skimage.io import imsave
import numpy as np

# %%
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Conv2DTranspose
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras import backend as K

from data import load_train_data, load_test_data
# Out:
# Using TensorFlow backend.

# %%
img_rows = 96
img_cols = 96

smooth = 1.

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
def get_unet():
    inputs = Input((img_rows, img_cols, 1))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])

    model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss, metrics=[dice_coef])

    return model

# %%
def preprocess(imgs):
    imgs_p = np.ndarray((imgs.shape[0], img_rows, img_cols), dtype=np.uint8)
    for i in range(imgs.shape[0]):
        imgs_p[i] = resize(imgs[i], (img_cols, img_rows), preserve_range=True)

    imgs_p = imgs_p[..., np.newaxis]
    return imgs_p

# %%
print('-'*30)
print('Loading and preprocessing train data...')
print('-'*30)
imgs_train, imgs_mask_train = load_train_data()
# Out:
# ------------------------------
# Loading and preprocessing train data...
# ------------------------------

# %%
imgs_train = preprocess(imgs_train)
imgs_mask_train = preprocess(imgs_mask_train)
# Out:
# /notebooks/lib/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
imgs_train = imgs_train.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization

# %%
imgs_train -= mean
imgs_train /= std

imgs_mask_train = imgs_mask_train.astype('float32')
imgs_mask_train /= 255.  # scale masks to [0, 1]

# %%
print('-'*30)
print('Creating and compiling model...')
print('-'*30)
model = get_unet()
model_checkpoint = ModelCheckpoint('weights.h5', monitor='val_loss', save_best_only=True)
# Out:
# ------------------------------
# Creating and compiling model...
# ------------------------------

# %%
print('-'*30)
print('Fitting model...')
print('-'*30)
model.fit(imgs_train, imgs_mask_train, batch_size=32, epochs=20, verbose=1, shuffle=True,
          validation_split=0.2,
          callbacks=[model_checkpoint])
# Out:
# ------------------------------
# Fitting model...
# ------------------------------
# Train on 4508 samples, validate on 1127 samples
# Epoch 1/20
# 4508/4508 [==============================] - 20s 4ms/step - loss: -0.0250 - dice_coef: 0.0250 - val_loss: -0.0284 - val_dice_coef: 0.0284
# Epoch 2/20
# 4508/4508 [==============================] - 16s 4ms/step - loss: -0.0970 - dice_coef: 0.0970 - val_loss: -0.2402 - val_dice_coef: 0.2402
# Epoch 3/20
# 4508/4508 [==============================] - 15s 3ms/step - loss: -0.2549 - dice_coef: 0.2549 - val_loss: -0.2564 - val_dice_coef: 0.2564
# Epoch 4/20
# 4508/4508 [==============================] - 15s 3ms/step - loss: -0.2681 - dice_coef: 0.2681 - val_loss: -0.2709 - val_dice_coef: 0.2709
# Epoch 5/20
# 4508/4508 [==============================] - 15s 3ms/step - loss: -0.2917 - dice_coef: 0.2917 - val_loss: -0.2829 - val_dice_coef: 0.2829
# Epoch 6/20
# 4508/4508 [==============================] - 15s 3ms/step - loss: -0.3041 - dice_coef: 0.3041 - val_loss: -0.2952 - val_dice_coef: 0.2952
# Epoch 7/20
# 4508/4508 [==============================] - 15s 3ms/step - loss: -0.3266 - dice_coef: 0.3266 - val_loss: -0.2860 - val_dice_coef: 0.2860
# Epoch 8/20
# 4508/4508 [==============================] - 16s 3ms/step - loss: -0.3195 - dice_coef: 0.3195 - val_loss: -0.3394 - val_dice_coef: 0.3394
# Epoch 9/20
# 4508/4508 [==============================] - 15s 3ms/step - loss: -0.3605 - dice_coef: 0.3605 - val_loss: -0.3662 - val_dice_coef: 0.3662
# Epoch 10/20
# 4508/4508 [==============================] - 16s 3ms/step - loss: -0.3937 - dice_coef: 0.3937 - val_loss: -0.3995 - val_dice_coef: 0.3995
# Epoch 11/20
# 4508/4508 [==============================] - 16s 3ms/step - loss: -0.4163 - dice_coef: 0.4163 - val_loss: -0.4224 - val_dice_coef: 0.4224
# Epoch 12/20
# 4508/4508 [==============================] - 15s 3ms/step - loss: -0.4397 - dice_coef: 0.4397 - val_loss: -0.4184 - val_dice_coef: 0.4184
# Epoch 13/20
# 4508/4508 [==============================] - 16s 3ms/step - loss: -0.4580 - dice_coef: 0.4580 - val_loss: -0.4376 - val_dice_coef: 0.4376
# Epoch 14/20
# 4508/4508 [==============================] - 15s 3ms/step - loss: -0.4715 - dice_coef: 0.4715 - val_loss: -0.4638 - val_dice_coef: 0.4638
# Epoch 15/20
# 4508/4508 [==============================] - 15s 3ms/step - loss: -0.4864 - dice_coef: 0.4864 - val_loss: -0.4743 - val_dice_coef: 0.4743
# Epoch 16/20
# 4508/4508 [==============================] - 15s 3ms/step - loss: -0.4954 - dice_coef: 0.4954 - val_loss: -0.4807 - val_dice_coef: 0.4807
# Epoch 17/20
# 4508/4508 [==============================] - 15s 3ms/step - loss: -0.4997 - dice_coef: 0.4997 - val_loss: -0.4676 - val_dice_coef: 0.4676
# Epoch 18/20
# 4508/4508 [==============================] - 16s 3ms/step - loss: -0.5112 - dice_coef: 0.5112 - val_loss: -0.4932 - val_dice_coef: 0.4932
# Epoch 19/20
# 4508/4508 [==============================] - 15s 3ms/step - loss: -0.5198 - dice_coef: 0.5198 - val_loss: -0.5059 - val_dice_coef: 0.5059
# Epoch 20/20
# 4508/4508 [==============================] - 16s 3ms/step - loss: -0.5212 - dice_coef: 0.5212 - val_loss: -0.5156 - val_dice_coef: 0.5156

# %%
print('-'*30)
print('Loading and preprocessing test data...')
print('-'*30)
imgs_test, imgs_id_test = load_test_data()
imgs_test = preprocess(imgs_test)

imgs_test = imgs_test.astype('float32')
imgs_test -= mean
imgs_test /= std
# Out:
# ------------------------------
# Loading and preprocessing test data...
# ------------------------------

# %%
print('-'*30)
print('Loading saved weights...')
print('-'*30)
model.load_weights('weights.h5')
# Out:
# ------------------------------
# Loading saved weights...
# ------------------------------

# %%
print('-'*30)
print('Predicting masks on test data...')
print('-'*30)
imgs_mask_test = model.predict(imgs_test, verbose=1)
np.save(os.environ['DATA_DIR']+os.sep+'imgs_mask_test.npy', imgs_mask_test)
# Out:
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# 5508/5508 [==============================] - 5s 980us/step

# %%
print('-' * 30)
print('Saving predicted masks to files...')
print('-' * 30)
pred_dir = os.environ['TRAINING_DIR']
if not os.path.exists(pred_dir):
    os.mkdir(pred_dir)
for image, image_id in zip(imgs_mask_test, imgs_id_test):
    image = (image[:, :, 0] * 255.).astype(np.uint8)
    imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# Out:
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/1111_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/1181_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/1203_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/1423_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/1427_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/1512_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/1598_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/196_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2031_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/223_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2324_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2344_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2462_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2501_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3248_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3353_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3497_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3538_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3700_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3718_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3719_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3798_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3909_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3921_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/4024_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/4211_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/4265_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/4274_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/4307_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/4332_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/4667_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/4759_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/495_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/5131_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/5158_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/5198_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/5477_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/617_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/626_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/637_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/848_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/912_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/1058_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/1292_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/1457_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/1465_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/1665_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/1681_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/1915_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2049_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2112_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2213_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2274_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2573_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2634_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2771_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2776_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2839_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2882_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2958_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3128_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3138_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3546_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3551_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3632_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3661_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3668_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/4029_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/4085_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/4146_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/4328_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/4562_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/5150_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/542_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/585_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/91_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/923_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/932_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/945_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2079_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/21_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2130_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2220_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2275_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2294_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/245_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2564_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2576_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2708_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2781_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/2991_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/3202_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /notebooks/lib/skimage/io/_io.py:132: UserWarning: /notebooks/training/